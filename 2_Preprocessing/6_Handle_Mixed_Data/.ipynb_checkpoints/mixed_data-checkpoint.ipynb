# %%
import pandas as pd

# %%
data = pd.read_csv("./data.csv")
data.head()
# Out:
#   Cabin            Ticket number  Survived
# 0   NaN         A/5 21171      5         0
# 1   C85          PC 17599      3         1
# 2   NaN  STON/O2. 3101282      6         1
# 3  C123            113803      3         1
# 4   NaN            373450      A         0

# %% [markdown]
# # Working on number

# %%
data.number.unique()
# Out:
# array(['5', '3', '6', 'A', '2', '1', '4'], dtype=object)

# %%
fig = data.number.value_counts().plot.bar()
fig.set_title("Passengers Range")
# Out:
# Text(0.5, 1.0, 'Passengers Range')

# %%
data.number.value_counts()
# Out:
# A    139
# 6    131
# 1    129
# 4    126
# 2    126
# 5    123
# 3    117
# Name: number, dtype: int64

# %% [markdown]
# # Extract numbers

# %%
data["number_numeric"]=pd.to_numeric(data.number,errors="coerce")

# %%
data.head()
# Out:
#   Cabin            Ticket number  Survived  number_numeric
# 0   NaN         A/5 21171      5         0             5.0
# 1   C85          PC 17599      3         1             3.0
# 2   NaN  STON/O2. 3101282      6         1             6.0
# 3  C123            113803      3         1             3.0
# 4   NaN            373450      A         0             NaN

# %% [markdown]
# # Extract Categorical data in number

# %%
data["number_categorical"]=np.where(data.number_numeric.isnull(),data.number,np.nan)

# %%
data.head()
# Out:
#   Cabin            Ticket number  Survived  number_numeric number_categorical
# 0   NaN         A/5 21171      5         0             5.0                NaN
# 1   C85          PC 17599      3         1             3.0                NaN
# 2   NaN  STON/O2. 3101282      6         1             6.0                NaN
# 3  C123            113803      3         1             3.0                NaN
# 4   NaN            373450      A         0             NaN                  A

# %% [markdown]
# # Working on Cabin data

# %%
data.Cabin.unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
data["Cabin_num"] = data.Cabin.str.extract("(\d+)")

# %%
data.head()
# Out:
#   Cabin            Ticket number  Survived  number_numeric number_categorical  \
# 0   NaN         A/5 21171      5         0             5.0                NaN
# 1   C85          PC 17599      3         1             3.0                NaN
# 2   NaN  STON/O2. 3101282      6         1             6.0                NaN
# 3  C123            113803      3         1             3.0                NaN
# 4   NaN            373450      A         0             NaN                  A
#
#   Cabin_num
# 0       NaN
# 1        85
# 2       NaN
# 3       123
# 4       NaN

# %%
data["Cabin_cat"] = data.Cabin.str[0]
# 0 is the first INDEX e.g C85 0 is C

# %%
data.head()
# Out:
#   Cabin            Ticket number  Survived  number_numeric number_categorical  \
# 0   NaN         A/5 21171      5         0             5.0                NaN
# 1   C85          PC 17599      3         1             3.0                NaN
# 2   NaN  STON/O2. 3101282      6         1             6.0                NaN
# 3  C123            113803      3         1             3.0                NaN
# 4   NaN            373450      A         0             NaN                  A
#
#   Cabin_num Cabin_cat
# 0       NaN       NaN
# 1        85         C
# 2       NaN       NaN
# 3       123         C
# 4       NaN       NaN

# %%
data.Cabin_cat.unique()
# Out:
# array([nan, 'C', 'E', 'G', 'D', 'A', 'B', 'F', 'T'], dtype=object)

# %% [markdown]
# # Working on Ticket data

# %%
data["ticket_number"] = data.Ticket.apply(lambda i:i.split()[-1])

# %%
data.head()
# Out:
#   Cabin            Ticket number  Survived  number_numeric number_categorical  \
# 0   NaN         A/5 21171      5         0             5.0                NaN
# 1   C85          PC 17599      3         1             3.0                NaN
# 2   NaN  STON/O2. 3101282      6         1             6.0                NaN
# 3  C123            113803      3         1             3.0                NaN
# 4   NaN            373450      A         0             NaN                  A
#
#   Cabin_num Cabin_cat ticket_number
# 0       NaN       NaN         21171
# 1        85         C         17599
# 2       NaN       NaN       3101282
# 3       123         C        113803
# 4       NaN       NaN        373450

# %%
data["ticket_number"] = pd.to_numeric(data.Ticket,errors="coerce",downcast="integer")

# %%
data
# Out:
#     Cabin            Ticket number  Survived  number_numeric  \
# 0     NaN         A/5 21171      5         0             5.0
# 1     C85          PC 17599      3         1             3.0
# 2     NaN  STON/O2. 3101282      6         1             6.0
# 3    C123            113803      3         1             3.0
# 4     NaN            373450      A         0             NaN
# ..    ...               ...    ...       ...             ...
# 886   NaN            211536      3         0             3.0
# 887   B42            112053      3         1             3.0
# 888   NaN        W./C. 6607      1         0             1.0
# 889  C148            111369      2         1             2.0
# 890   NaN            370376      3         0             3.0
#
#     number_categorical Cabin_num Cabin_cat  ticket_number
# 0                  NaN       NaN       NaN            NaN
# 1                  NaN        85         C            NaN
# ...

# %%
data["ticket_cat"] = data.Ticket.apply(lambda x:x.split()[0])

# %%
data
# Out:
#     Cabin            Ticket number  Survived  number_numeric  \
# 0     NaN         A/5 21171      5         0             5.0
# 1     C85          PC 17599      3         1             3.0
# 2     NaN  STON/O2. 3101282      6         1             6.0
# 3    C123            113803      3         1             3.0
# 4     NaN            373450      A         0             NaN
# ..    ...               ...    ...       ...             ...
# 886   NaN            211536      3         0             3.0
# 887   B42            112053      3         1             3.0
# 888   NaN        W./C. 6607      1         0             1.0
# 889  C148            111369      2         1             2.0
# 890   NaN            370376      3         0             3.0
#
#     number_categorical Cabin_num Cabin_cat  ticket_number ticket_cat
# 0                  NaN       NaN       NaN            NaN        A/5
# 1                  NaN        85         C            NaN         PC
# ...

# %%
data["ticket_cat"] = np.where(data.Ticket.str.isdigit(),np.nan,data.ticket_cat                             )

# %%
data
# Out:
#     Cabin            Ticket number  Survived  number_numeric  \
# 0     NaN         A/5 21171      5         0             5.0
# 1     C85          PC 17599      3         1             3.0
# 2     NaN  STON/O2. 3101282      6         1             6.0
# 3    C123            113803      3         1             3.0
# 4     NaN            373450      A         0             NaN
# ..    ...               ...    ...       ...             ...
# 886   NaN            211536      3         0             3.0
# 887   B42            112053      3         1             3.0
# 888   NaN        W./C. 6607      1         0             1.0
# 889  C148            111369      2         1             2.0
# 890   NaN            370376      3         0             3.0
#
#     number_categorical Cabin_num Cabin_cat  ticket_number ticket_cat
# 0                  NaN       NaN       NaN            NaN        A/5
# 1                  NaN        85         C            NaN         PC
# ...

# %% [markdown]
# # New Data

# %%
new = pd.DataFrame(data.Cabin_cat)
new["Cabin_num"] = data.Cabin_num

new["ticket_number"] = data.ticket_number
new["ticket_cat"] = data.ticket_cat

new["number_numeric"] = data.number_numeric
new["number_categorical"] = data.number_categorical

new["Surived"] = data.Survived

# %%
new
# Out:
#     Cabin_cat Cabin_num  ticket_number ticket_cat  number_numeric  \
# 0         NaN       NaN            NaN        A/5             5.0
# 1           C        85            NaN         PC             3.0
# 2         NaN       NaN            NaN   STON/O2.             6.0
# 3           C       123       113803.0        NaN             3.0
# 4         NaN       NaN       373450.0        NaN             NaN
# ..        ...       ...            ...        ...             ...
# 886       NaN       NaN       211536.0        NaN             3.0
# 887         B        42       112053.0        NaN             3.0
# 888       NaN       NaN            NaN      W./C.             1.0
# 889         C       148       111369.0        NaN             2.0
# 890       NaN       NaN       370376.0        NaN             3.0
#
#     number_categorical  Surived
# 0                  NaN        0
# 1                  NaN        1
# 2                  NaN        1
# 3                  NaN        1
# ...
