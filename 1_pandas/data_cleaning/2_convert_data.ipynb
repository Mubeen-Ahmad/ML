# %%
import pandas as pd
df = pd.read_csv("dirtydata.csv")

# %% [markdown]
# # pd.to_datetime()

# %%
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# 16        60  '2020/12/16'     98       120     215.2
# 17        60  '2020/12/17'    100       120     300.0
# 18        45  '2020/12/18'     90       112       NaN
# 19        60  '2020/12/19'    103       123     323.0
# 20        45  '2020/12/20'     97       125     243.0
# 21        60  '2020/12/21'    108       131     364.2
# 22        45           NaN    100       119     282.0
# 23        60  '2020/12/23'    130       101     300.0
# 24        45  '2020/12/24'    105       132     246.0
# 25        60  '2020/12/25'    102       126     334.5
# 26        60      20201226    100       120     250.0
# 27        60  '2020/12/27'     92       118     241.0
# 28        60  '2020/12/28'    103       132       NaN
# 29        60  '2020/12/29'    100       132     280.0
# 30        60  '2020/12/30'    102       129     380.3
# 31        60  '2020/12/31'     92       115     243.0

# %% [markdown]
# # to_datetime

# %%
new = pd.to_datetime(df['Date'])
new
# Out:
# 0    2020-12-01
# 1    2020-12-02
# 2    2020-12-03
# 3    2020-12-04
# 4    2020-12-05
# 5    2020-12-06
# 6    2020-12-07
# 7    2020-12-08
# 8    2020-12-09
# 9    2020-12-10
# 10   2020-12-11
# 11   2020-12-12
# 12   2020-12-12
# 13   2020-12-13
# 14   2020-12-14
# 15   2020-12-15
# 16   2020-12-16
# 17   2020-12-17
# 18   2020-12-18
# 19   2020-12-19
# 20   2020-12-20
# 21   2020-12-21
# 22          NaT
# 23   2020-12-23
# 24   2020-12-24
# 25   2020-12-25
# 26   2020-12-26
# 27   2020-12-27
# 28   2020-12-28
# 29   2020-12-29
# 30   2020-12-30
# 31   2020-12-31
# Name: Date, dtype: datetime64[ns]

# %% [markdown]
# # to_numeric()

# %%
pd.to_numeric(new)
# Out:
# 0     1606780800000000000
# 1     1606867200000000000
# 2     1606953600000000000
# 3     1607040000000000000
# 4     1607126400000000000
# 5     1607212800000000000
# 6     1607299200000000000
# 7     1607385600000000000
# 8     1607472000000000000
# 9     1607558400000000000
# 10    1607644800000000000
# 11    1607731200000000000
# 12    1607731200000000000
# 13    1607817600000000000
# 14    1607904000000000000
# 15    1607990400000000000
# 16    1608076800000000000
# 17    1608163200000000000
# 18    1608249600000000000
# 19    1608336000000000000
# 20    1608422400000000000
# 21    1608508800000000000
# 22   -9223372036854775808
# 23    1608681600000000000
# 24    1608768000000000000
# 25    1608854400000000000
# 26    1608940800000000000
# 27    1609027200000000000
# 28    1609113600000000000
# 29    1609200000000000000
# 30    1609286400000000000
# 31    1609372800000000000
# Name: Date, dtype: int64

# %% [markdown]
# # df.to_string()

# %%
new.to_string()
# Out:
# '0    2020-12-01\n1    2020-12-02\n2    2020-12-03\n3    2020-12-04\n4    2020-12-05\n5    2020-12-06\n6    2020-12-07\n7    2020-12-08\n8    2020-12-09\n9    2020-12-10\n10   2020-12-11\n11   2020-12-12\n12   2020-12-12\n13   2020-12-13\n14   2020-12-14\n15   2020-12-15\n16   2020-12-16\n17   2020-12-17\n18   2020-12-18\n19   2020-12-19\n20   2020-12-20\n21   2020-12-21\n22          NaT\n23   2020-12-23\n24   2020-12-24\n25   2020-12-25\n26   2020-12-26\n27   2020-12-27\n28   2020-12-28\n29   2020-12-29\n30   2020-12-30\n31   2020-12-31'

# %%
rep = df["Duration"].mode()[0]
for i in df.index:
    if df.loc[i,"Duration"] > rep:
        print(df.loc[i,""])
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/pandas/core/indexes/base.py:2898, in Index.get_loc(self, key, method, tolerance)
#    2897 try:
# -> 2898     return self._engine.get_loc(casted_key)
#    2899 except KeyError as err:
#
# File pandas/_libs/index.pyx:70, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:101, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:1675, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:1683, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [54], in <cell line: 2>()
#       2 for i in df.index:
#       3     if df.loc[i,"Duration"] > rep:
# ----> 4         print(df.loc[i,""])
#       5 df
#
# File /usr/lib/python3/dist-packages/pandas/core/indexing.py:873, in _LocationIndexer.__getitem__(self, key)
#     870         except (KeyError, IndexError, AttributeError):
#     871             # AttributeError for IntervalTree get_value
#     872             pass
# --> 873     return self._getitem_tuple(key)
#     874 else:
#     875     # we by definition only have the 0th axis
#     876     axis = self.axis or 0
#
# File /usr/lib/python3/dist-packages/pandas/core/indexing.py:1044, in _LocIndexer._getitem_tuple(self, tup)
#    1042 def _getitem_tuple(self, tup: Tuple):
#    1043     try:
# -> 1044         return self._getitem_lowerdim(tup)
#    1045     except IndexingError:
#    1046         pass
#
# File /usr/lib/python3/dist-packages/pandas/core/indexing.py:810, in _LocationIndexer._getitem_lowerdim(self, tup)
#     808             return section
#     809         # This is an elided recursive call to iloc/loc
# --> 810         return getattr(section, self.name)[new_key]
#     812 raise IndexingError("not applicable")
#
# File /usr/lib/python3/dist-packages/pandas/core/indexing.py:879, in _LocationIndexer.__getitem__(self, key)
#     876 axis = self.axis or 0
#     878 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879 return self._getitem_axis(maybe_callable, axis=axis)
#
# File /usr/lib/python3/dist-packages/pandas/core/indexing.py:1110, in _LocIndexer._getitem_axis(self, key, axis)
#    1108 # fall thru to straight lookup
#    1109 self._validate_key(key, axis)
# -> 1110 return self._get_label(key, axis=axis)
#
# File /usr/lib/python3/dist-packages/pandas/core/indexing.py:1059, in _LocIndexer._get_label(self, label, axis)
#    1057 def _get_label(self, label, axis: int):
#    1058     # GH#5667 this will fail if the label is not present in the axis.
# -> 1059     return self.obj.xs(label, axis=axis)
#
# File /usr/lib/python3/dist-packages/pandas/core/generic.py:3493, in NDFrame.xs(self, key, axis, level, drop_level)
#    3491     loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3492 else:
# -> 3493     loc = self.index.get_loc(key)
#    3495     if isinstance(loc, np.ndarray):
#    3496         if loc.dtype == np.bool_:
#
# File /usr/lib/python3/dist-packages/pandas/core/indexes/base.py:2900, in Index.get_loc(self, key, method, tolerance)
#    2898         return self._engine.get_loc(casted_key)
#    2899     except KeyError as err:
# -> 2900         raise KeyError(key) from err
#    2902 if tolerance is not None:
#    2903     tolerance = self._convert_tolerance(tolerance, np.asarray(key))
#
# KeyError: ''
